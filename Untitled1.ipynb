# %% [markdown]
# <a href="https://colab.research.google.com/github/vova52228/vvsu/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input ()
match (a):
  case "400":
   print ("Bad Request")
  case "401":
   print ("Unauthorized")
  case "402":
   print ("Payment Required")
  case "403":
   print ("Forbidden")
  case "404":
   print ("Not Found")
  case "405":
   print ("Method Not Allowed")
# Out:
# 404
# Not Found

# %%
X = int(input("X = "))
Y = int(input("Y = "))
if X > 0 and Y > 0:
  print ("Первая четверть")
elif X < 0 and Y < 0:
  print ("Третья четверть")
elif X < 0 and Y > 0:
  print ("Вторая четверть")
else:
  print ("Четвертая четверть")
# Out:
# X = 2
# Y = 2
# Первая четверть

# %%
year = int(input("Текущий год:"))
if year % 4 == 0:
  print("DA")
elif year % 100 == 0 and year % 400 == 0:
  print("DA")
else:
  print("NET")
# Out:
# Текущий год:2145
# NET

# %%
a = int(input("a = "))
b = int(input("b = "))
print(((b != 0) and a/b) or ("Деление невозможно"))
# Out:
# a = 1
# b = 0
# Деление невозможно
