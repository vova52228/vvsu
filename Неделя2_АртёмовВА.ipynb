# %% [markdown]
# <a href="https://colab.research.google.com/github/vova52228/vvsu/blob/main/%D0%9D%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F2_%D0%90%D1%80%D1%82%D1%91%D0%BC%D0%BE%D0%B2%D0%92%D0%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача №1

# %%
a = int(input())
b = int(input())
c = (a**2 + b**2)**0.5
print(c)
# Out:
# 3
# 4
# 5.0

# %% [markdown]
# Задача №2

# %%
num = int(input())
print("The next number for the number" + " " + str(num) + " " + "is" + " " + str(num + 1))
print("The previous number for the number" + " " + str(num) + " " + "is" + " " + str(num - 1))
# Out:
# 4
# The next number for the number 4 is 5
# The previous number for the number 4 is 3

# %% [markdown]
# Задача №3

# %%
x = int(input())
print(x//1000-x%10 + x//100%10-x//10%10 + 1)
# Out:
# 1000
# 2

# %% [markdown]
# Задача №4

# %%
h = int(input())
a = int(input())
b = int(input())
print(1 + (h - a) // (a - b))
# Out:
# 30
# 15
# 10
# 4

# %% [markdown]
# Задача №5

# %%
n = int(input())
h = (n // 3600) % 24
n = n % 3600
m = (n // 60)
if m < 10:
    m = "0" + str(m)
s = n % 60
if s < 10:
    s = "0" + str(s)

print(h, m, s, sep=':')
# Out:
# 2500
# 0:41:40

# %% [markdown]
# Задача №6

# %%
t1=list(map(int,input().split(':')))
t2=list(map(int,input().split(':')))

s1=t1[0]*3600+t1[1]*60+t1[2]
s2=t2[0]*3600+t2[1]*60+t2[2]

a = s2 - s1

h = a // 3600
a = a %3600
m = a // 60
s = a %60

print(h,m,s)
# Out:
# 14:30:20
# 17:50:10
# 3 19 50

# %% [markdown]
# Задача №7

# %%
a = int(input())
b = int(input())
a += b
b = a - b
a = a - b
print(a, b)
# Out:
# 1
# 3
# 3 1

# %% [markdown]
# Задача №8

# %%
n = int(input())
k = int(input())
print(-k % n)
# Out:
# 10
# 7
# 3

# %% [markdown]
# Задача №9

# %%
n = int(input())
a = n % 10
n = n // 10
b = n % 10
n = n // 10
print(n + a + b)
# Out:
# 139
# 13
